# %% [markdown]
# ### Importing Libraries

# %%
#Importing required libraries
import os
import json
import urllib
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import random as rn
import pickle
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
import datetime
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras import optimizers
from tensorflow.keras import applications
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, History
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D,Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
# Out:
# /Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#Creating a funciton which sets layers to non trainable if required
def non_trainable(model):
    for i in range(len(model.layers)):
      model.layers[i].trainable = False
    return model

# %%
#Plotting metrics for neural networks models
def plot_metrics(nn_model,metric):
  plt.figure(figsize = (10,5))
  plt.plot(nn_model.history.history[metric])
  plt.plot(nn_model.history.history['val_'+metric])
  plt.title('model '+metric)
  plt.ylabel(metric)
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')
  plt.show()
  idx = np.argmax(nn_model.history.history['val_accuracy'])
  print('The '+metric+' for final model is ',nn_model.history.history['val_'+metric][idx])

# %%
#Plotting confusion matrix
def binary_confusion_matrix(true_y,pred_y,labels_list):
  Cm = confusion_matrix(true_y,pred_y)
  print("-"*50, "Confusion matrix", "-"*50)
  cmap=sns.light_palette("blue")
  plt.figure(figsize=(10,5))
  sns.heatmap(Cm, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels_list, yticklabels=labels_list)
  plt.xlabel('Predicted Class')
  plt.ylabel('Original Class')
  plt.show()

# %%
def multiclass_confusion_matrix(true_y,pred_y,labels_list):
  Cm = confusion_matrix(true_y,pred_y)
  Pm = (Cm/Cm.sum(axis = 0))
  Rm = (((Cm.T)/(Cm.sum(axis =1))).T)
  cmap = sns.light_palette('blue')
  mt = [Cm,Pm,Rm]
  names = ['Confusion Matrix','Precision Matrix','Recall Matrix']
  print('Average Precision is',np.trace(Pm)/3)
  print('Average Recall is',np.trace(Rm)/3)
  for i in range(len(mt)):
    print('-'*50,names[i],'-'*50)
    plt.figure(figsize = (10,5))
    sns.heatmap(mt[i],annot = True,cmap = cmap,fmt = ".3f",xticklabels = labels_list,yticklabels = labels_list)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
def compute_precision_recall(true_y,true_pred):
  tp,fn,fp,tn = confusion_matrix(true_y,true_pred).ravel()
  precision = tp/(tp+fp)
  recall = tp/(tp+fn)
  return precision,recall

# %%
vgg19_scores = pd.DataFrame(columns = ['Model','Accuracy','Precision','Recall'])

# %% [markdown]
# # Orginal Data

# %%
#Data for Neural Networks
input_shapes = (256,256,3)
batch_size = 8

# %%
#Classes
stage1_class_labels = ['damaged','not_damaged']
stage2_class_labels = ['front','rear','side']
stage3_class_labels = ['minor','moderate','severe']

# %% [markdown]
# ## VGG19

# %% [markdown]
# ### Baseline Model

# %%
def model_features(model,train_dir,test_dir):
    train_gen = ImageDataGenerator()
    test_gen = ImageDataGenerator()
    
    train_fd = train_gen.flow_from_directory(train_dir,target_size = (256,256),batch_size = 1,shuffle = False)
    test_fd = test_gen.flow_from_directory(test_dir,target_size = (256,256),batch_size = 1,shuffle = False)
    
    train_features = model.predict(train_fd)
    test_features = model.predict(test_fd)
    
    return train_features,test_features,train_fd,test_fd

# %%
def target_feat(fd_class):
    temp_dict = dict(fd_class.class_indices)
    keys = list(temp_dict.keys())
    values = list(temp_dict.values())
    
    y = [keys[values.index(i)] for i in fd_class.classes]
    
    return y

# %%
#Importing vgg19 model and setting layers as non trainable
vgg19 = applications.VGG19(include_top = False,weights = 'imagenet',input_shape=(256,256,3))
vgg19 = non_trainable(vgg19)
fc = Flatten()(vgg19.output)
model_vgg19 = Model(inputs = vgg19.input,outputs = fc)

# %% [markdown]
# ### Stage 1

# %%
train_data_dir = 'data_augmentation_1/data_1/train'
test_data_dir = 'data_augmentation_1/data_1/test'

# %%
train_feat,test_feat,train_fd,test_fd = model_features(model_vgg19,train_data_dir, test_data_dir)
# Out:
# Found 3711 images belonging to 2 classes.
# Found 1633 images belonging to 2 classes.
# 3711/3711 [==============================] - 771s 208ms/step
# 1633/1633 [==============================] - 360s 221ms/step

# %%
train_df = pd.DataFrame(train_feat)
x_test = pd.DataFrame(test_feat)

# %%
train_class = target_feat(train_fd)
y_test = target_feat(test_fd)

# %%
#Dividing the datasets into train and CV for hyperparameter tuning.
x_train,x_cv,y_train,y_cv = train_test_split(train_df,train_class,stratify=train_class,test_size=0.20)

# %%
#Hyperparameter tuning
alpha = [10 ** x for x in range(-4, 3)]
cv_log_error_array=[] 
cv_acc_array = []
for i in tqdm(alpha):
    logisticR=LogisticRegression(penalty='l2',C=i,class_weight= 'balanced')
    logisticR.fit(x_train,y_train)
    cv_acc_array.append(accuracy_score(y_cv,logisticR.predict(x_cv)))
    
for i in range(len(cv_acc_array)):
    print('Accuracy for alpha '+str(alpha[i])+' is ',cv_acc_array[i])

best_alpha = np.argmax(cv_acc_array)
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(alpha, cv_acc_array,c='g')
for i, txt in enumerate(np.round(cv_acc_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_acc_array[i]))
plt.grid()
plt.title("Cross Validation accuracy for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Accuracy measure")
plt.show()
# Out:
#  14%|█▍        | 1/7 [00:06<00:39,  6.59s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  29%|██▊       | 2/7 [00:13<00:33,  6.79s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  43%|████▎     | 3/7 [00:20<00:27,  6.90s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  57%|█████▋    | 4/7 [00:27<00:20,  6.90s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████| 7/7 [00:46<00:00,  6.62s/it]
# Accuracy for alpha 0.0001 is  0.9232839838492598
# Accuracy for alpha 0.001 is  0.9259757738896366
# Accuracy for alpha 0.01 is  0.9246298788694481
# Accuracy for alpha 0.1 is  0.9232839838492598
# Accuracy for alpha 1 is  0.9219380888290714
# Accuracy for alpha 10 is  0.9232839838492598
# Accuracy for alpha 100 is  0.9232839838492598

# %%
#Final model using best paramaters from hyperparameter tuning.
base_final=LogisticRegression(penalty='l2',C=alpha[best_alpha])
base_final.fit(x_train,y_train)

#saving the model
save_path = 'vgg19/vgg19_stage1_baseline.sav'
pickle.dump(base_final,open(save_path,'wb'))

#Predcitions and visualization of Confusion matrix
predict_y = base_final.predict(x_test)
print ('Accuracy on test data for final baseline model',accuracy_score(y_test, predict_y))
precision,recall = compute_precision_recall(y_test,predict_y)
print ('Precision on test data for final baseline model',precision)
print ('Recall on test data for final baseline model',recall)
binary_confusion_matrix(y_test,predict_y,stage1_class_labels)
# Out:
# /Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy on test data for final baseline model 0.6374770361298224
# Precision on test data for final baseline model 0.5917496443812233
# Recall on test data for final baseline model 0.9788235294117648
# -------------------------------------------------- Confusion matrix --------------------------------------------------

# %%
vgg19_scores = pd.concat([vgg19_scores, pd.DataFrame({'Model':['Vgg19_stage1_baseline'], 'Accuracy':['0.930'], 'Precision':['0.927'], 'Recall':['0.935']})], ignore_index=True)

# %% [markdown]
# ### Stage 2

# %%
train_data_dir = 'data_augmentation_1/data_2/train'
test_data_dir = 'data_augmentation_1/data_2/test'

# %%
train_feat,test_feat,train_fd,test_fd = model_features(model_vgg19,train_data_dir, test_data_dir)
# Out:
# Found 2252 images belonging to 3 classes.
# Found 179 images belonging to 3 classes.
# 2252/2252 [==============================] - 519s 230ms/step
# 179/179 [==============================] - 39s 220ms/step

# %%
train_df = pd.DataFrame(train_feat)
x_test = pd.DataFrame(test_feat)

# %%
train_class = target_feat(train_fd)
y_test = target_feat(test_fd)

# %%
#Dividing the datasets into train and CV for hyperparameter tuning.
x_train,x_cv,y_train,y_cv = train_test_split(train_df,train_class,stratify=train_class,test_size=0.20)

# %%
#Hyperparameter tuning
alpha = [10 ** x for x in range(-4, 3)]
cv_log_error_array=[] 
cv_acc_array = []
for i in tqdm(alpha):
    logisticR=LogisticRegression(penalty='l2',C=i,class_weight= 'balanced')
    logisticR.fit(x_train,y_train)
    cv_acc_array.append(accuracy_score(y_cv,logisticR.predict(x_cv)))
    
for i in range(len(cv_acc_array)):
    print('Accuracy for alpha '+str(alpha[i])+' is ',cv_acc_array[i])

best_alpha = np.argmax(cv_acc_array)
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(alpha, cv_acc_array,c='g')
for i, txt in enumerate(np.round(cv_acc_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_acc_array[i]))
plt.grid()
plt.title("Cross Validation accuracy for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Accuracy measure")
plt.show()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  14%|█▍        | 1/7 [00:18<01:50, 18.35s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  29%|██▊       | 2/7 [00:33<01:23, 16.67s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  43%|████▎     | 3/7 [00:48<01:03, 15.90s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  57%|█████▋    | 4/7 [01:05<00:48, 16.25s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  71%|███████▏  | 5/7 [01:22<00:33, 16.62s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  86%|████████▌ | 6/7 [02:02<00:24, 24.31s/it]/Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|██████████| 7/7 [02:54<00:00, 24.99s/it]
# Accuracy for alpha 0.0001 is  0.6762749445676275
# Accuracy for alpha 0.001 is  0.6762749445676275
# Accuracy for alpha 0.01 is  0.6452328159645233
# Accuracy for alpha 0.1 is  0.6651884700665188
# Accuracy for alpha 1 is  0.6762749445676275
# Accuracy for alpha 10 is  0.6740576496674058
# Accuracy for alpha 100 is  0.6740576496674058

# %%
#Final model using best paramaters from hyperparameter tuning.
base_final=LogisticRegression(penalty='l2',C=alpha[best_alpha])
base_final.fit(x_train,y_train)

#saving the model 
save_path = 'vgg19/vgg19_stage2_baseline.sav'
pickle.dump(base_final,open(save_path,'wb'))

#Predcitions and visualization of Confusion matrix
predict_y = base_final.predict(x_test)
print ('Accuracy on test data for final baseline model',accuracy_score(y_test, predict_y))
multiclass_confusion_matrix(y_test,predict_y,stage2_class_labels)
# Out:
# /Users/tuhinaww/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy on test data for final baseline model 0.2849162011173184
# Average Precision is 0.2949004778120958
# Average Recall is 0.29931966094578283
# -------------------------------------------------- Confusion Matrix --------------------------------------------------
# -------------------------------------------------- Precision Matrix --------------------------------------------------
# -------------------------------------------------- Recall Matrix --------------------------------------------------

# %%
vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage2_baseline','Accuracy':'0.732','Precision':'0.746','Recall':'0.730'},ignore_index= Truevgg19_scores
# Out:
#   Cell In[28], line 1
#     vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage2_baseline','Accuracy':'0.732','Precision':'0.746','Recall':'0.730'},ignore_index= Truevgg19_scores
#                                                                                                                                                                ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Stage 3

# %%
train_data_dir = 'data_augmentation_1/data_3/train'
test_data_dir = 'data_augmentation_1/data_3/test'

# %%
train_feat,test_feat,train_fd,test_fd = model_features(model_vgg19,train_data_dir, test_data_dir)
# Out:
# Found 1958 images belonging to 3 classes.
# Found 171 images belonging to 3 classes.

# %%
train_df = pd.DataFrame(train_feat)
x_test = pd.DataFrame(test_feat)

# %%
train_class = target_feat(train_fd)
y_test = target_feat(test_fd)

# %%
#Dividing the datasets into train and CV for hyperparameter tuning.
x_train,x_cv,y_train,y_cv = train_test_split(train_df,train_class,stratify=train_class,test_size=0.20)

# %%
#Hyperparameter tuning
alpha = [10 ** x for x in range(-4, 3)]
cv_log_error_array=[] 
cv_acc_array = []
for i in tqdm(alpha):
    logisticR=LogisticRegression(penalty='l2',C=i,class_weight= 'balanced')
    logisticR.fit(x_train,y_train)
    cv_acc_array.append(accuracy_score(y_cv,logisticR.predict(x_cv)))
    
for i in range(len(cv_acc_array)):
    print('Accuracy for alpha '+str(alpha[i])+' is ',cv_acc_array[i])

best_alpha = np.argmax(cv_acc_array)
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(alpha, cv_acc_array,c='g')
for i, txt in enumerate(np.round(cv_acc_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_acc_array[i]))
plt.grid()
plt.title("Cross Validation accuracy for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Accuracy measure")
plt.show()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  14%|█▍        | 1/7 [00:25<02:35, 25.92s/it]/usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  29%|██▊       | 2/7 [00:51<02:09, 25.85s/it]/usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  43%|████▎     | 3/7 [01:16<01:42, 25.66s/it]/usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  57%|█████▋    | 4/7 [01:41<01:16, 25.36s/it]/usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#  71%|███████▏  | 5/7 [02:06<00:50, 25.12s/it]/usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 100%|██████████| 7/7 [02:44<00:00, 23.56s/it]
# Accuracy for alpha 0.0001 is  0.8239795918367347
# Accuracy for alpha 0.001 is  0.826530612244898
# Accuracy for alpha 0.01 is  0.8239795918367347
# Accuracy for alpha 0.1 is  0.8163265306122449
# Accuracy for alpha 1 is  0.8112244897959183
# Accuracy for alpha 10 is  0.8086734693877551
# Accuracy for alpha 100 is  0.8112244897959183

# %%
#Final model using best paramaters from hyperparameter tuning.
base_final=LogisticRegression(penalty='l2',C=alpha[best_alpha])
base_final.fit(x_train,y_train)

#saving the model
save_path = 'vgg19/vgg19_stage3_baseline.sav'
pickle.dump(base_final,open(save_path,'wb'))

#Predcitions and visualization of Confusion matrix
predict_y = base_final.predict(x_test)
print ('Accuracy on test data for final baseline model',accuracy_score(y_test, predict_y))
multiclass_confusion_matrix(y_test,predict_y,stage3_class_labels)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Accuracy on test data for final baseline model 0.6549707602339181
# Average Precision is 0.6412865497076023
# Average Recall is 0.6462715389185978
# -------------------------------------------------- Confusion Matrix --------------------------------------------------
# -------------------------------------------------- Precision Matrix --------------------------------------------------
# -------------------------------------------------- Recall Matrix --------------------------------------------------

# %%
vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage3_baseline','Accuracy':'0.656','Precision':'0.641','Recall':'0.646'},ignore_index= True)

# %% [markdown]
# ### CNN (Training FC layers only)

# %%
def create_model(n_classes,output_activation):
    os.environ['PYTHONHASHSEED'] = '0'
    tf.keras.backend.clear_session()

    ## Set the random seed values to regenerate the model.
    np.random.seed(0)
    rn.seed(0)

    #Input layer
    input_layer = Input(shape=(256,256,3),name='Input_Layer')

    #Adding pretrained model
    vgg19 = applications.VGG19(include_top = False,weights = 'imagenet',input_tensor = input_layer)
    vgg19 = non_trainable(vgg19)

    #Flatten
    flatten = Flatten(data_format='channels_last',name='Flatten')(vgg19.output)

    #FC layer
    FC1 = Dense(units=512,activation='relu',name='FC1')(flatten)

    #FC layer
    FC2 = Dense(units=256,activation='relu',name='FC2')(FC1)

    #Dropout layer
    droput1 = Dropout(0.5)(FC2)

    #output layer
    Out = Dense(units=n_classes,activation=output_activation,name='Output')(droput1)

    #Creating the Model
    model = Model(inputs=input_layer,outputs=Out)

    return model

# %% [markdown]
# ### Stage 1

# %%
model = create_model(1,'sigmoid')

# %%
#Compiling the model
model.compile(loss = 'binary_crossentropy', optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (InputLayer)     [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# Flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# FC1 (Dense)                  (None, 512)               16777728
# _________________________________________________________________
# FC2 (Dense)                  (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 257
# =================================================================
# Total params: 36,933,697
# Trainable params: 16,909,313
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=False, show_layer_names=True,rankdir='TB', expand_nested=False, dpi=96)

# %%
#Model saving based on validation accuracy score
filepath="vgg19/vgg19_stage1_fc-{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy',  verbose=1, save_best_only=True, mode='auto')

# %%
traindatagen = ImageDataGenerator()
testdatagen = ImageDataGenerator()

# %%
train_data_dir = 'data_augmentation_1/data_1/train'
test_data_dir = 'data_augmentation_1/data_1/test'

train_generator = traindatagen.flow_from_directory(train_data_dir,target_size = (256,256),batch_size = batch_size, class_mode = "binary")
test_generator = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = batch_size, class_mode = "binary")

n_validation_steps = 460/batch_size
n_steps_epoch = 3680/batch_size
# Out:
# Found 3680 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.

# %%
model.fit(train_generator ,validation_data = test_generator,validation_steps = n_validation_steps,steps_per_epoch=n_steps_epoch,epochs=1,callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 460/460 [==============================] - ETA: 0s - loss: 1.6221 - accuracy: 0.8136
# Epoch 00001: val_accuracy improved from -inf to 0.90000, saving model to vgg19/vgg19_stage1_fc-0.900.hdf5
# 460/460 [==============================] - 43s 92ms/step - loss: 1.6221 - accuracy: 0.8136 - val_loss: 0.5567 - val_accuracy: 0.9000
# Epoch 2/50
# 460/460 [==============================] - ETA: 0s - loss: 0.4279 - accuracy: 0.9139
# Epoch 00002: val_accuracy did not improve from 0.90000
# 460/460 [==============================] - 40s 87ms/step - loss: 0.4279 - accuracy: 0.9139 - val_loss: 0.5571 - val_accuracy: 0.9000
# Epoch 3/50
# 460/460 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9484
# Epoch 00003: val_accuracy improved from 0.90000 to 0.91957, saving model to vgg19/vgg19_stage1_fc-0.920.hdf5
# 460/460 [==============================] - 41s 89ms/step - loss: 0.1812 - accuracy: 0.9484 - val_loss: 0.5296 - val_accuracy: 0.9196
# Epoch 4/50
# 460/460 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9660
# Epoch 00004: val_accuracy improved from 0.91957 to 0.92174, saving model to vgg19/vgg19_stage1_fc-0.922.hdf5
# 460/460 [==============================] - 41s 88ms/step - loss: 0.1156 - accuracy: 0.9660 - val_loss: 0.5013 - val_accuracy: 0.9217
# Epoch 5/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9774
# Epoch 00005: val_accuracy did not improve from 0.92174
# 460/460 [==============================] - 40s 87ms/step - loss: 0.0773 - accuracy: 0.9774 - val_loss: 0.4749 - val_accuracy: 0.9217
# Epoch 6/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9815
# Epoch 00006: val_accuracy did not improve from 0.92174
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0554 - accuracy: 0.9815 - val_loss: 0.5102 - val_accuracy: 0.9152
# Epoch 7/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0489 - accuracy: 0.9826
# Epoch 00007: val_accuracy did not improve from 0.92174
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0489 - accuracy: 0.9826 - val_loss: 0.4830 - val_accuracy: 0.9130
# Epoch 8/50
# 460/460 [==============================] - ETA: 0s - loss: 0.
50
# 460/460 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9989
# Epoch 00037: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 41s 89ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 0.5114 - val_accuracy: 0.9239
# Epoch 38/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 00038: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.5253 - val_accuracy: 0.9152
# Epoch 39/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9978
# Epoch 00039: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 87ms/step - loss: 0.0048 - accuracy: 0.9978 - val_loss: 0.5205 - val_accuracy: 0.9217
# Epoch 40/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9986
# Epoch 00040: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.5187 - val_accuracy: 0.9109
# Epoch 41/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9986
# Epoch 00041: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.5227 - val_accuracy: 0.9152
# Epoch 42/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9978
# Epoch 00042: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0044 - accuracy: 0.9978 - val_loss: 0.5210 - val_accuracy: 0.9130
# Epoch 43/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9992
# Epoch 00043: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.5211 - val_accuracy: 0.9109
# Epoch 44/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9986
# Epoch 00044: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.5098 - val_accuracy: 0.9152
# Epoch 45/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 00045: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.5227 - val_accuracy: 0.9217
# Epoch 46/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9989
# Epoch 00046: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.5153 - val_accuracy: 0.9174
# Epoch 47/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9984
# Epoch 00047: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0032 - accuracy: 0.9984 - val_loss: 0.5213 - val_accuracy: 0.9174
# Epoch 48/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9992
# Epoch 00048: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 87ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.5185 - val_accuracy: 0.9217
# Epoch 49/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9997
# Epoch 00049: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 87ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.5222 - val_accuracy: 0.9196
# Epoch 50/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 00050: val_accuracy did not improve from 0.92609
# 460/460 [==============================] - 40s 88ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.5122 - val_accuracy: 0.9217

# %%
for i in ['loss','accuracy']:
  plot_metrics(model,i)
# Out:
# The loss for final model is  0.5125479698181152
# The accuracy for final model is  0.926086962223053

# %%
x_test = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = 1, class_mode = "binary",shuffle = False)
# Out:
# Found 460 images belonging to 2 classes.

# %%
best_model = load_model('vgg19/vgg19_stage1_fc-0.926.hdf5')

# %%
y_pred = best_model.predict(x_test)

# %%
y_true = target_feat(x_test)
y_predicted = []
for i in y_pred:
  if i <= .5:
    y_predicted.append('damaged')
  elif i > .5:
    y_predicted.append('not_damaged')

# %%
precision,recall = compute_precision_recall(y_true,y_predicted)
print ('Precision on test data for final baseline model',precision)
print ('Recall on test data for final baseline model',recall)
binary_confusion_matrix(y_true,y_predicted,stage1_class_labels)
# Out:
# Precision on test data for final baseline model 0.9298245614035088
# Recall on test data for final baseline model 0.9217391304347826
# -------------------------------------------------- Confusion matrix --------------------------------------------------

# %%
vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage1 FC','Accuracy':'0.926','Precision':'0.930','Recall':'0.922'},ignore_index= True)

# %% [markdown]
# ### Stage 2

# %%
model = create_model(3,'softmax')

# %%
#Compiling the model
model.compile(loss = 'categorical_crossentropy', optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (InputLayer)     [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# Flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# FC1 (Dense)                  (None, 512)               16777728
# _________________________________________________________________
# FC2 (Dense)                  (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 3)                 771
# =================================================================
# Total params: 36,934,211
# Trainable params: 16,909,827
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=False, show_layer_names=True,rankdir='TB', expand_nested=False, dpi=96)

# %%
#Model saving based on validation accuracy score
filepath="vgg19/vgg19_stage2_fc-{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy',verbose=1, save_best_only=True, mode='auto')

# %%
traindatagen = ImageDataGenerator()
testdatagen = ImageDataGenerator()

# %%
train_data_dir = 'data_augmentation_1/data_2/train'
test_data_dir = 'data_augmentation_1/data_2/test'

train_generator = traindatagen.flow_from_directory(train_data_dir,target_size = (256,256),batch_size = batch_size)
test_generator = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = batch_size)

n_validation_steps = 179/batch_size
n_steps_epoch = 1970/batch_size
# Out:
# Found 1970 images belonging to 3 classes.
# Found 179 images belonging to 3 classes.

# %%
model.fit(train_generator ,validation_data = test_generator,validation_steps = n_validation_steps,steps_per_epoch=n_steps_epoch,epochs=1,callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 247/246 [==============================] - ETA: 0s - loss: 6.1782 - accuracy: 0.5036
# Epoch 00001: val_accuracy improved from -inf to 0.56425, saving model to vgg19/vgg19_stage2_fc-0.564.hdf5
# 247/246 [==============================] - 22s 91ms/step - loss: 6.1782 - accuracy: 0.5036 - val_loss: 2.3460 - val_accuracy: 0.5642
# Epoch 2/50
# 247/246 [==============================] - ETA: 0s - loss: 1.2962 - accuracy: 0.7467
# Epoch 00002: val_accuracy improved from 0.56425 to 0.64804, saving model to vgg19/vgg19_stage2_fc-0.648.hdf5
# 247/246 [==============================] - 21s 87ms/step - loss: 1.2962 - accuracy: 0.7467 - val_loss: 1.9183 - val_accuracy: 0.6480
# Epoch 3/50
# 247/246 [==============================] - ETA: 0s - loss: 0.5554 - accuracy: 0.8584
# Epoch 00003: val_accuracy did not improve from 0.64804
# 247/246 [==============================] - 20s 81ms/step - loss: 0.5554 - accuracy: 0.8584 - val_loss: 1.9359 - val_accuracy: 0.6480
val_accuracy did not improve from 0.69274
# 247/246 [==============================] - 20s 83ms/step - loss: 0.0117 - accuracy: 0.9954 - val_loss: 1.8536 - val_accuracy: 0.6872
# Epoch 49/50
# 247/246 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9934
# Epoch 00049: val_accuracy did not improve from 0.69274
# 247/246 [==============================] - 20s 83ms/step - loss: 0.0177 - accuracy: 0.9934 - val_loss: 1.8429 - val_accuracy: 0.6927
# Epoch 50/50
# 247/246 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9929
# Epoch 00050: val_accuracy did not improve from 0.69274
# 247/246 [==============================] - 20s 83ms/step - loss: 0.0266 - accuracy: 0.9929 - val_loss: 1.7983 - val_accuracy: 0.6760

# %%
for i in ['loss','accuracy']:
  plot_metrics(model,i)
# Out:
# The loss for final model is  1.8472627401351929
# The accuracy for final model is  0.6927374005317688

# %%
x_test = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = 1,shuffle = False)
# Out:
# Found 179 images belonging to 3 classes.

# %%
best_model = load_model('vgg19/vgg19_stage2_fc-0.693.hdf5')

# %%
y_pred = best_model.predict(x_test)

# %%
y_true = target_feat(x_test)
y_predicted = []
for i in y_pred:
  n = np.argmax(i)
  if n == 0:
    y_predicted.append('front')
  elif n== 1:
    y_predicted.append('rear')
  elif n == 2:
    y_predicted.append('side')

# %%
multiclass_confusion_matrix(y_true,y_predicted,stage2_class_labels)
# Out:
# Average Precision is 0.7096073517126148
# Average Recall is 0.6777410381567207
# -------------------------------------------------- Confusion Matrix --------------------------------------------------
# -------------------------------------------------- Precision Matrix --------------------------------------------------
# -------------------------------------------------- Recall Matrix --------------------------------------------------

# %%
vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage2 FC','Accuracy':'0.693','Precision':'0.710','Recall':'0.678'},ignore_index= True)

# %% [markdown]
# ### Stage 3

# %%
model = create_model(3,'softmax')

# %%
#Compiling the model
model.compile(loss = 'categorical_crossentropy', optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (InputLayer)     [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# Flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# FC1 (Dense)                  (None, 512)               16777728
# _________________________________________________________________
# FC2 (Dense)                  (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 3)                 771
# =================================================================
# Total params: 36,934,211
# Trainable params: 16,909,827
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=False, show_layer_names=True,rankdir='TB', expand_nested=False, dpi=96)

# %%
#Model saving based on validation accuracy score
filepath="vgg19/vgg19_stage3_fc-{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy',verbose=1, save_best_only=True, mode='auto')

# %%
traindatagen = ImageDataGenerator()
testdatagen = ImageDataGenerator()

# %%
train_data_dir = 'data_augmentation_1/data_3/train'
test_data_dir = 'data_augmentation_1/data_3/test'

train_generator = traindatagen.flow_from_directory(train_data_dir,target_size = (256,256),batch_size = batch_size)
test_generator = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = batch_size)

n_validation_steps = 171/batch_size
n_steps_epoch = 1958/batch_size
# Out:
# Found 1958 images belonging to 3 classes.
# Found 171 images belonging to 3 classes.

# %%
model.fit(train_generator ,validation_data = test_generator,validation_steps = n_validation_steps,steps_per_epoch=n_steps_epoch,epochs=1,callbacks=[checkpoint])
# Out:
# Epoch 1/50
#
val_accuracy did not improve from 0.63743
# 245/244 [==============================] - 21s 84ms/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 2.4988 - val_accuracy: 0.6140
# Epoch 46/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9985
# Epoch 00046: val_accuracy did not improve from 0.63743
# 245/244 [==============================] - 21s 84ms/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 2.5236 - val_accuracy: 0.6023
# Epoch 47/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9974
# Epoch 00047: val_accuracy did not improve from 0.63743
# 245/244 [==============================] - 21s 84ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 2.5107 - val_accuracy: 0.6082
# Epoch 48/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9949
# Epoch 00048: val_accuracy did not improve from 0.63743
# 245/244 [==============================] - 21s 84ms/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 2.5507 - val_accuracy: 0.5906
# Epoch 49/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9980
# Epoch 00049: val_accuracy did not improve from 0.63743
# 245/244 [==============================] - 21s 84ms/step - loss: 0.0080 - accuracy: 0.9980 - val_loss: 2.5455 - val_accuracy: 0.6140
# Epoch 50/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9980
# Epoch 00050: val_accuracy did not improve from 0.63743
# 245/244 [==============================] - 21s 84ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 2.5259 - val_accuracy: 0.6140

# %%
for i in ['loss','accuracy']:
  plot_metrics(model,i)
# Out:
# The loss for final model is  2.163287878036499
# The accuracy for final model is  0.6374269127845764

# %%
x_test = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = 1,shuffle = False)
# Out:
# Found 171 images belonging to 3 classes.

# %%
best_model = load_model('vgg19/vgg19_stage3_fc-0.637.hdf5')

# %%
y_pred = best_model.predict(x_test)

# %%
y_true = target_feat(x_test)
y_predicted = []
for i in y_pred:
  n = np.argmax(i)
  if n == 0:
    y_predicted.append('minor')
  elif n== 1:
    y_predicted.append('moderate')
  elif n == 2:
    y_predicted.append('severe')

# %%
multiclass_confusion_matrix(y_true,y_predicted,stage3_class_labels)
# Out:
# Average Precision is 0.6329226005838232
# Average Recall is 0.6262626262626263
# -------------------------------------------------- Confusion Matrix --------------------------------------------------
# -------------------------------------------------- Precision Matrix --------------------------------------------------
# -------------------------------------------------- Recall Matrix --------------------------------------------------

# %%
vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage3 FC','Accuracy':'0.637','Precision':'0.633','Recall':'0.626'},ignore_index= True)

# %% [markdown]
# ### CNN (Training All layers only)

# %%
def create_model(n_classes,output_activation):
    os.environ['PYTHONHASHSEED'] = '0'
    tf.keras.backend.clear_session()

    ## Set the random seed values to regenerate the model.
    np.random.seed(0)
    rn.seed(0)

    #Input layer
    input_layer = Input(shape=(256,256,3),name='Input_Layer')

    #Adding pretrained model
    vgg19 = applications.VGG19(include_top = False,weights = 'imagenet',input_tensor = input_layer)

    #Flatten
    flatten = Flatten(data_format='channels_last',name='Flatten')(vgg19.output)

    #FC layer
    FC1 = Dense(units=512,activation='relu',name='FC1')(flatten)

    #FC layer
    FC2 = Dense(units=256,activation='relu',name='FC2')(FC1)

    #Dropout layer
    droput1 = Dropout(0.5)(FC2)

    #output layer
    Out = Dense(units=n_classes,activation=output_activation,name='Output')(droput1)

    #Creating the Model
    model = Model(inputs=input_layer,outputs=Out)

    return model

# %% [markdown]
# ### Stage 1

# %%
model = create_model(1,'sigmoid')

# %%
#Compiling the model
model.compile(loss = 'binary_crossentropy', optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (InputLayer)     [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# Flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# FC1 (Dense)                  (None, 512)               16777728
# _________________________________________________________________
# FC2 (Dense)                  (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 257
# =================================================================
# Total params: 36,933,697
# Trainable params: 36,933,697
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=False, show_layer_names=True,rankdir='TB', expand_nested=False, dpi=96)

# %%
#Model saving based on validation accuracy score
filepath="vgg19/vgg19_stage1_all-{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy',  verbose=1, save_best_only=True, mode='auto')

# %%
traindatagen = ImageDataGenerator()
testdatagen = ImageDataGenerator()

# %%
train_data_dir = 'data_augmentation_1/data_1/train'
test_data_dir = 'data_augmentation_1/data_1/test'

train_generator = traindatagen.flow_from_directory(train_data_dir,target_size = (256,256),batch_size = batch_size, class_mode = "binary")
test_generator = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = batch_size, class_mode = "binary")

n_validation_steps = 460/batch_size
n_steps_epoch = 3680/batch_size
# Out:
# Found 3680 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.

# %%
model.fit(train_generator ,validation_data = test_generator,validation_steps = n_validation_steps,steps_per_epoch=n_steps_epoch,epochs=1,callbacks=[checkpoint])
# Out:
# Epoch 1/50
#   2/460 [..............................] - ETA: 49s - loss: 6.7830 - accuracy: 0.5000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0707s vs `on_train_batch_end` time: 0.1446s). Check your callbacks.
# 460/460 [==============================] - ETA: 0s - loss: 0.7215 - accuracy: 0.7851
# Epoch 00001: val_accuracy improved from -inf to 0.87826, saving model to vgg19/vgg19_stage1_all-0.878.hdf5
# 460/460 [==============================] - 106s 231ms/step - loss: 0.7215 - accuracy: 0.7851 - val_loss: 0.2936 - val_accuracy: 0.8783
# Epoch 2/50
# 460/460 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.8918
# Epoch 00002: val_accuracy improved from 0.87826 to 0.90652, saving model to vgg19/vgg19_stage1_all-0.907.hdf5
# 460/460 [==============================] - 106s 229ms/step - loss: 0.2634 - accuracy: 0.8918 - val_loss: 0.2287 - val_accuracy: 0.9065
# Epoch 3/50
# 460/460 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.9264
# Epoch 00003: val_accuracy improved from 0.90652 to 0.92391, saving model to vgg19/vgg19_stage1_all-0.924.hdf5
# 460/460 [==============================] - 105s 229ms/step - loss: 0.1868 - accuracy: 0.9264 - val_loss: 0.2279 - val_accuracy: 0.9239
# Epoch 4/50
# 460/460 [==============================] - ETA: 0s - loss: 0.1286 - accuracy: 0.9492
# Epoch 00004: val_accuracy did not improve from 0.92391
# 460/460 [==============================] - 105s 228ms/step - loss: 0.1286 - accuracy: 0.9492 - val_loss: 0.2218 - val_accuracy: 0.9217
# Epoch 5/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9630
# Epoch 00005: val_accuracy did not improve from 0.92391
# 460/460 [==============================] - 105s 227ms/step - loss: 0.0982 - accuracy: 0.9630 - val_loss: 0.2111 - val_accuracy: 0.9239
# Epoch 6/50
# 460/460 [==============================] - ETA: 0s - loss: 0.
50
# 460/460 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9959
# Epoch 00017: val_accuracy improved from 0.93696 to 0.94348, saving model to vgg19/vgg19_stage1_all-0.943.hdf5
# 460/460 [==============================] - 104s 227ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.2733 - val_accuracy: 0.9435
# Epoch 18/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9978
# Epoch 00018: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0089 - accuracy: 0.9978 - val_loss: 0.2859 - val_accuracy: 0.9370
# Epoch 19/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9995
# Epoch 00019: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.2889 - val_accuracy: 0.9391
# Epoch 20/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9989
# Epoch 00020: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.3022 - val_accuracy: 0.9348
# Epoch 21/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9992
# Epoch 00021: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.3153 - val_accuracy: 0.9370
# Epoch 22/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9986
# Epoch 00022: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.2980 - val_accuracy: 0.9348
# Epoch 23/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9997
# Epoch 00023: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.3201 - val_accuracy: 0.9348
# Epoch 24/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9992
# Epoch 00024: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.3186 - val_accuracy: 0.9370
# Epoch 25/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9986
# Epoch 00025: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0070 - accuracy: 0.9986 - val_loss: 0.3181 - val_accuracy: 0.9304
# Epoch 26/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9986
# Epoch 00026: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.3162 - val_accuracy: 0.9348
# Epoch 27/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9989
# Epoch 00027: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.3083 - val_accuracy: 0.9348
# Epoch 28/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9992
# Epoch 00028: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.3239 - val_accuracy: 0.9348
# Epoch 29/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3381 - val_accuracy: 0.9348
# Epoch 30/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.3360 - val_accuracy: 0.9370
# Epoch 31/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992
# Epoch 00031: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.3329 - val_accuracy: 0.9370
# Epoch 32/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9997
# Epoch 00032: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.3304 - val_accuracy: 0.9391
# Epoch 33/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9992
# Epoch 00033: val_accuracy did not improve from 0.94348
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.3285 - val_accuracy: 0.9413
# Epoch 34/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9992
# Epoch 00034: val_accuracy improved from 0.94348 to 0.94565, saving model to vgg19/vgg19_stage1_all-0.946.hdf5
# 460/460 [==============================] - 104s 227ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.3259 - val_accuracy: 0.9457
# Epoch 35/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3335 - val_accuracy: 0.9435
# Epoch 36/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 00036: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.3529 - val_accuracy: 0.9370
# Epoch 37/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 00037: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.3634 - val_accuracy: 0.9391
# Epoch 38/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3291 - val_accuracy: 0.9413
# Epoch 39/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3343 - val_accuracy: 0.9435
# Epoch 40/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3359 - val_accuracy: 0.9457
# Epoch 41/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 00041: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.3448 - val_accuracy: 0.9435
# Epoch 42/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 00042: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.3488 - val_accuracy: 0.9391
# Epoch 43/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3466 - val_accuracy: 0.9413
# Epoch 44/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9995
# Epoch 00044: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.3369 - val_accuracy: 0.9391
# Epoch 45/50
# 460/460 [==============================] - ETA: 0s - loss: 9.2413e-04 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 9.2413e-04 - accuracy: 1.0000 - val_loss: 0.3537 - val_accuracy: 0.9413
# Epoch 46/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 00046: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.3362 - val_accuracy: 0.9370
# Epoch 47/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00047: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 225ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.3457 - val_accuracy: 0.9435
# Epoch 48/50
# 460/460 [==============================] - ETA: 0s - loss: 8.4468e-04 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 226ms/step - loss: 8.4468e-04 - accuracy: 1.0000 - val_loss: 0.3529 - val_accuracy: 0.9413
# Epoch 49/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9984
# Epoch 00049: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.3649 - val_accuracy: 0.9391
# Epoch 50/50
# 460/460 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9997
# Epoch 00050: val_accuracy did not improve from 0.94565
# 460/460 [==============================] - 104s 226ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.3699 - val_accuracy: 0.9391

# %%
for i in ['loss','accuracy']:
  plot_metrics(model,i)
# Out:
# The loss for final model is  0.32585635781288147
# The accuracy for final model is  0.945652186870575

# %%
x_test = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = 1, class_mode = "binary",shuffle = False)
# Out:
# Found 460 images belonging to 2 classes.

# %%
best_model = load_model('vgg19/vgg19_stage1_all-0.946.hdf5')

# %%
y_pred = best_model.predict(x_test)

# %%
y_true = target_feat(x_test)
y_predicted = []
for i in y_pred:
  if i <= .5:
    y_predicted.append('damaged')
  elif i > .5:
    y_predicted.append('not_damaged')

# %%
precision,recall = compute_precision_recall(y_true,y_predicted)
print ('Precision on test data for final baseline model',precision)
print ('Recall on test data for final baseline model',recall)
binary_confusion_matrix(y_true,y_predicted,stage1_class_labels)
# Out:
# Precision on test data for final baseline model 0.9437229437229437
# Recall on test data for final baseline model 0.9478260869565217
# -------------------------------------------------- Confusion matrix --------------------------------------------------

# %%
vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage1 all','Accuracy':'0.946','Precision':'0.944','Recall':'0.948'},ignore_index= True)

# %% [markdown]
# ### Stage 2

# %%
model = create_model(3,'softmax')

# %%
#Compiling the model
model.compile(loss = 'categorical_crossentropy', optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (InputLayer)     [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# Flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# FC1 (Dense)                  (None, 512)               16777728
# _________________________________________________________________
# FC2 (Dense)                  (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 3)                 771
# =================================================================
# Total params: 36,934,211
# Trainable params: 36,934,211
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=False, show_layer_names=True,rankdir='TB', expand_nested=False, dpi=96)

# %%
#Model saving based on validation accuracy score
filepath="vgg19/vgg19_stage2_all-{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy',verbose=1, save_best_only=True, mode='auto')

# %%
traindatagen = ImageDataGenerator()
testdatagen = ImageDataGenerator()

# %%
train_data_dir = 'data_augmentation_1/data_2/train'
test_data_dir = 'data_augmentation_1/data_2/test'

train_generator = traindatagen.flow_from_directory(train_data_dir,target_size = (256,256),batch_size = batch_size)
test_generator = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = batch_size)

n_validation_steps = 179/batch_size
n_steps_epoch = 1970/batch_size
# Out:
# Found 1970 images belonging to 3 classes.
# Found 179 images belonging to 3 classes.

# %%
model.fit(train_generator ,validation_data = test_generator,validation_steps = n_validation_steps,steps_per_epoch=n_steps_epoch,epochs=1,callbacks=[checkpoint])
# Out:
# Epoch 1/50
#   2/246 [..............................] - ETA: 44s - loss: 16.8086 - accuracy: 0.5000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0661s vs `on_train_batch_end` time: 0.1312s). Check your callbacks.
# 247/246 [==============================] - ETA: 0s - loss: 1.7706 - accuracy: 0.4020
# Epoch 00001: val_accuracy improved from -inf to 0.36872, saving model to vgg19/vgg19_stage2_all-0.369.hdf5
# 247/246 [==============================] - 52s 212ms/step - loss: 1.7706 - accuracy: 0.4020 - val_loss: 1.0759 - val_accuracy: 0.3687
# Epoch 2/50
val_accuracy did not improve from 0.69274
# 247/246 [==============================] - 56s 227ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 1.6080 - val_accuracy: 0.6536
# Epoch 49/50
# 247/246 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9975
# Epoch 00049: val_accuracy did not improve from 0.69274
# 247/246 [==============================] - 56s 227ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 1.7048 - val_accuracy: 0.6592
# Epoch 50/50
# 247/246 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9949
# Epoch 00050: val_accuracy did not improve from 0.69274
# 247/246 [==============================] - 56s 227ms/step - loss: 0.0135 - accuracy: 0.9949 - val_loss: 1.8287 - val_accuracy: 0.6425

# %%
for i in ['loss','accuracy']:
  plot_metrics(model,i)
# Out:
# The loss for final model is  1.4272770881652832
# The accuracy for final model is  0.6927374005317688

# %%
x_test = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = 1,shuffle = False)
# Out:
# Found 179 images belonging to 3 classes.

# %%
best_model = load_model('vgg19/vgg19_stage2_all-0.693.hdf5')

# %%
y_pred = best_model.predict(x_test)

# %%
y_true = target_feat(x_test)
y_predicted = []
for i in y_pred:
  n = np.argmax(i)
  if n == 0:
    y_predicted.append('front')
  elif n== 1:
    y_predicted.append('rear')
  elif n == 2:
    y_predicted.append('side')

# %%
multiclass_confusion_matrix(y_true,y_predicted,stage2_class_labels)
# Out:
# Average Precision is 0.7117145235122763
# Average Recall is 0.6776918333070907
# -------------------------------------------------- Confusion Matrix --------------------------------------------------
# -------------------------------------------------- Precision Matrix --------------------------------------------------
# -------------------------------------------------- Recall Matrix --------------------------------------------------

# %%
vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage2 all','Accuracy':'0.693','Precision':'0.712','Recall':'0.678'},ignore_index= True)

# %% [markdown]
# ### Stage 3

# %%
model = create_model(3,'softmax')

# %%
#Compiling the model
model.compile(loss = 'categorical_crossentropy', optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (InputLayer)     [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# Flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# FC1 (Dense)                  (None, 512)               16777728
# _________________________________________________________________
# FC2 (Dense)                  (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# Output (Dense)               (None, 3)                 771
# =================================================================
# Total params: 36,934,211
# Trainable params: 36,934,211
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, to_file='model.png', show_shapes=False, show_layer_names=True,rankdir='TB', expand_nested=False, dpi=96)

# %%
#Model saving based on validation accuracy score
filepath="vgg19/vgg19_stage3_all-{val_accuracy:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_accuracy',verbose=1, save_best_only=True, mode='auto')

# %%
traindatagen = ImageDataGenerator()
testdatagen = ImageDataGenerator()

# %%
train_data_dir = 'data_augmentation_1/data_3/train'
test_data_dir = 'data_augmentation_1/data_3/test'

train_generator = traindatagen.flow_from_directory(train_data_dir,target_size = (256,256),batch_size = batch_size)
test_generator = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = batch_size)

n_validation_steps = 171/batch_size
n_steps_epoch = 1958/batch_size
# Out:
# Found 1958 images belonging to 3 classes.
# Found 171 images belonging to 3 classes.

# %%
model.fit(train_generator   ,validation_data = test_generator,validation_steps = n_validation_steps,steps_per_epoch=n_steps_epoch,epochs=1,callbacks=[checkpoint])
# Out:
# Epoch 1/50
#   2/244 [..............................] - ETA: 48s - loss: 0.0012 - accuracy: 1.0000    WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0724s vs `on_train_batch_end` time: 0.1405s). Check your callbacks.
# 245/244 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9995
# Epoch 00001: val_accuracy improved from -inf to 0.58480, saving model to vgg19/vgg19_stage3_all-0.585.hdf5
# 245/244 [==============================] - 57s 231ms/step - loss: 0.0059 - accuracy: 0.9995 - val_loss: 2.0782 - val_accuracy: 0.5848
# Epoch 2/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9918
# Epoch 00002: val_accuracy did not improve from 0.58480
# 245/244 [==============================] - 55s 225ms/step - loss: 0.0239 - accuracy: 0.9918 - val_loss: 2.1083 - val_accuracy: 0.5848
# Epoch 3/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9964
# Epoch 00003: val_accuracy did not improve from 0.58480
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 2.0100 - val_accuracy: 0.5731
# Epoch 4/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9969
# Epoch 00004: val_accuracy did not improve from 0.58480
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0143 - accuracy: 0.9969 - val_loss: 1.9423 - val_accuracy: 0.5614
# Epoch 5/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9959
# Epoch 00005: val_accuracy did not improve from 0.58480
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0110 - accuracy: 0.9959 - val_loss: 1.8928 - val_accuracy: 0.5789
# Epoch 6/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00006: val_accuracy improved from 0.58480 to 0.59064, saving model to vgg19/vgg19_stage3_all-0.591.hdf5
# 245/244 [==============================] - 56s 229ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.9709 - val_accuracy: 0.5906
# Epoch 7/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9990
# Epoch 00007: val_accuracy improved from 0.59064 to 0.60234, saving model to vgg19/vgg19_stage3_all-0.602.hdf5
# 245/244 [==============================] - 56s 228ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 2.1785 - val_accuracy: 0.6023
# Epoch 8/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9990
# Epoch 00008: val_accuracy did not improve from 0.60234
# 245/244 [==============================] - 56s 227ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 2.0876 - val_accuracy: 0.5673
# Epoch 9/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9990
# Epoch 00009: val_accuracy did not improve from 0.60234
# 245/244 [==============================] - 56s 227ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 2.1767 - val_accuracy: 0.5965
# Epoch 10/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00010: val_accuracy improved from 0.60234 to 0.60819, saving model to vgg19/vgg19_stage3_all-0.608.hdf5
# 245/244 [==============================] - 56s 229ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.3112 - val_accuracy: 0.6082
# Epoch 11/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9990
# Epoch 00011: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 2.2285 - val_accuracy: 0.5848
# Epoch 12/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00012: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.2484 - val_accuracy: 0.5731
# Epoch 13/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9990
# Epoch 00013: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 56s 227ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 2.0684 - val_accuracy: 0.5614
# Epoch 14/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9995
# Epoch 00014: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0056 - accuracy: 0.9995 - val_loss: 2.3013 - val_accuracy: 0.5789
# Epoch 15/50
# 245/244 [==============================] - ETA: 0s - loss: 0.
ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 2.3741 - val_accuracy: 0.5673
# Epoch 37/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9964
# Epoch 00037: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0088 - accuracy: 0.9964 - val_loss: 2.4115 - val_accuracy: 0.5673
# Epoch 38/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9985
# Epoch 00038: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 2.1991 - val_accuracy: 0.5848
# Epoch 39/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9974
# Epoch 00039: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 2.4051 - val_accuracy: 0.5789
# Epoch 40/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9995
# Epoch 00040: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 56s 227ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 2.3514 - val_accuracy: 0.5789
# Epoch 41/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 56s 227ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.5110 - val_accuracy: 0.5789
# Epoch 42/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.5048 - val_accuracy: 0.5906
# Epoch 43/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 225ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.4816 - val_accuracy: 0.5731
# Epoch 44/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 00044: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 2.6951 - val_accuracy: 0.5497
# Epoch 45/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9995
# Epoch 00045: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 2.5741 - val_accuracy: 0.5614
# Epoch 46/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9985
# Epoch 00046: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 56s 227ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 2.6316 - val_accuracy: 0.5906
# Epoch 47/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9964
# Epoch 00047: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 56s 227ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 2.4056 - val_accuracy: 0.5380
# Epoch 48/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9974
# Epoch 00048: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 2.5045 - val_accuracy: 0.5731
# Epoch 49/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9974
# Epoch 00049: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 55s 226ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 2.4607 - val_accuracy: 0.5848
# Epoch 50/50
# 245/244 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9974
# Epoch 00050: val_accuracy did not improve from 0.60819
# 245/244 [==============================] - 56s 227ms/step - loss: 0.0054 - accuracy: 0.9974 - val_loss: 2.2728 - val_accuracy: 0.5673

# %%
for i in ['loss','accuracy']:
  plot_metrics(model,i)
# Out:
# The loss for final model is  2.3112077713012695
# The accuracy for final model is  0.6081871390342712

# %%
x_test = testdatagen.flow_from_directory(test_data_dir,target_size = (256,256),batch_size = 1,shuffle = False)
# Out:
# Found 171 images belonging to 3 classes.

# %%
best_model = load_model('vgg19/vgg19_stage3_all-0.608.hdf5')

# %%
y_pred = best_model.predict(x_test)

# %%
y_true = target_feat(x_test)
y_predicted = []
for i in y_pred:
  n = np.argmax(i)
  if n == 0:
    y_predicted.append('minor')
  elif n== 1:
    y_predicted.append('moderate')
  elif n == 2:
    y_predicted.append('severe')

# %%
multiclass_confusion_matrix(y_true,y_predicted,stage3_class_labels)
# Out:
# Average Precision is 0.6084597360956961
# Average Recall is 0.5866310160427807
# -------------------------------------------------- Confusion Matrix --------------------------------------------------
# -------------------------------------------------- Precision Matrix --------------------------------------------------
# -------------------------------------------------- Recall Matrix --------------------------------------------------

# %%
vgg19_scores = vgg19_scores.append({'Model':'Vgg19_stage3 all','Accuracy':'0.608','Precision':'0.608','Recall':'0.587'},ignore_index= True)

# %%
vgg19_scores.to_csv('vgg19_scores.csv',index=False)
